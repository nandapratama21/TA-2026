# %% [markdown]
# # 01 - Build GenImage Manifest

# %%
# !python3 ../src/pipeline_modular/build_manifest_genimage.py --raw-root ../data/raw/genimage --output ../data/genimage_manifest.csv

# %%
import pandas as pd
df = pd.read_csv('../data/genimage_manifest.csv')
df.head(), df['generator'].value_counts().head(), df['class_name'].value_counts()
